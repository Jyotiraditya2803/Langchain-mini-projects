# %%
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

load_dotenv()

llm = init_chat_model("groq:llama-3.3-70b-versatile")

with open("bloods_report.txt", "r") as f:
    blood_work = f.read()
print(blood_work[:250])
# Out:
# Patient: Rajesh Sharma, Age 48, Male
# Date: May 7, 2026
#
# COMPLETE BLOOD COUNT (CBC)
# --------------------------
# Hemoglobin:        15.1 g/dL        (Normal: 13.5â€“17.5)
# Hematocrit:        44%              (Normal: 41â€“53%)
# WBC:               6.8 x10^

# %%
extraction_prompt = f"""
You are a medical data extraction assistant.

From the blood report below, extract ALL test values and classify each one as HIGH, LOW, or NORMAL based on the reference ranges provided in the report.

Format your response as:
- Test Name: value | Status: HIGH/LOW/NORMAL | Reference: range

Blood Report:
{blood_work}
"""

responese_prompt =llm.invoke(extraction_prompt)
answer = responese_prompt.text
print(answer)
# Out:
# Here are the extracted test values with their corresponding status and reference ranges:
#
# 1. **Hemoglobin**: 15.1 g/dL | Status: NORMAL | Reference: 13.5–17.5 g/dL
# 2. **Hematocrit**: 44% | Status: NORMAL | Reference: 41–53%
# 3. **WBC**: 6.8 x10^3/uL | Status: NORMAL | Reference: 4.5–11.0 x10^3/uL
# 4. **Platelets**: 220 x10^3/uL | Status: NORMAL | Reference: 150–400 x10^3/uL
# 5. **Total Cholesterol**: 238 mg/dL | Status: HIGH | Reference: <200 mg/dL
# 6. **LDL Cholesterol**: 162 mg/dL | Status: HIGH | Reference: <100 mg/dL
# 7. **HDL Cholesterol**: 36 mg/dL | Status: LOW | Reference: >40 mg/dL
# 8. **Triglycerides**: 188 mg/dL | Status: HIGH | Reference: <150 mg/dL
# 9. **Glucose (Fasting)**: 92 mg/dL | Status: NORMAL | Reference: 70–99 mg/dL
# 10. **HbA1c**: 5.3% | Status: NORMAL | Reference: <5.7%
# 11. **Creatinine**: 1.0 mg/dL | Status: NORMAL | Reference: 0.7–1.3 mg/dL
# 12. **eGFR**: 82 mL/min | Status: NORMAL | Reference: >60 mL/min
# 13. **ALT**: 28 U/L | Status: NORMAL | Reference: 7–40 U/L
# 14. **AST**: 25 U/L | Status: NORMAL | Reference: 10–40 U/L
# 15. **Bilirubin Total**: 0.8 mg/dL | Status: NORMAL | Reference: 0.2–1.2 mg/dL

# %%
diet_prompt = f"""
You are a clinical nutritionist specializing in Indian dietary habits.

Based on the blood work analysis below, write:
1. A short health summary in 4-5 lines explaining the patient's condition in simple language
2. A short, practical Indian diet plan having only two sections (1) Foods to avoid (2) Foods to eat more of.
   Do not include any other sections in diet plan.

Blood Work Analysis:
{answer}
"""
responese_prompt =llm.invoke(diet_prompt)
answer = responese_prompt.text
print(answer)
# Out:
# **Health Summary**
# The patient has high levels of total cholesterol, LDL cholesterol, and triglycerides, indicating an increased risk of heart disease. The patient's HDL cholesterol level is also low, which can further increase the risk of heart disease. However, the patient's blood sugar levels and other vital parameters are within normal range. With dietary changes, the patient can improve their cholesterol levels and reduce the risk of heart disease. Regular monitoring and lifestyle modifications are essential.
#
# **Diet Plan**
# (1) Foods to avoid
# - Fried foods like samosas, puris, and fried namkeens
# - High-fat dairy products like ghee, butter, and full-fat milk
# - Red meat and processed meat like sausages and bacon
# - Refined carbohydrates like white bread, sugary snacks, and sweetened beverages
# - Fried snacks like chips and bhujia
#
# (2) Foods to eat more of
# - Fruits like apples, bananas, and berries
# - Leafy green vegetables like spinach, methi, and sarson
# - Whole grains like brown rice, quinoa, and whole-wheat roti
# - Nuts and seeds like almonds, walnuts, and chia seeds
# - Low-fat dairy products like toned milk and low-fat yogurt
