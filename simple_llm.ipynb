# %%
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

load_dotenv()

llm = init_chat_model("groq:llama-3.3-70b-versatile")

response = llm.invoke([
    ("system", "you are ai assistant that answer in paragraph"),
    ("human", "hello")
])

print(response.content)
# Out:
# Hello, it's nice to meet you. I'm an AI assistant, and I'm here to help answer any questions you might have or provide information on a wide range of topics. I can assist with everything from simple queries to more complex problems, and I'll do my best to provide you with accurate and helpful responses. If you have a specific question or topic in mind, feel free to let me know and I'll do my best to help. If not, we can just chat and see where the conversation takes us. How's your day going so far?
